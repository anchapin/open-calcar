# %% [markdown]
# # **Surrogate Model**

# %% [markdown]
# ## **Load data**

# %%
import pandas as pd

df = pd.read_csv('')
df
# Out:
# 4.6.0

# %% [markdown]
# ## **Data prep**

# %% [markdown]
# ### Data separation as X and Y

# %%
y = df['']
y

# %%
x = df.drop('', axis=1)
x

# %% [markdown]
# ### Data splitting

# %% [markdown]
# ## **Data visualization of prediction results**

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
x = list(range(0,10))
y = list(range(-10,0))

plt.ylabel("Installed Cost in units of dollars")
plt.xlabel("Thermal comfort")

plt.plot(x,y)

# %%
plt.ylabel("Installed Cost in units of dollars")
plt.xlabel("Thermal comfort")

plt.scatter(x,y)
